# %%
set_var=set()
print(set_var)
print(type(set_var))
# Out:
# set()
# <class 'set'>

# %%
set_var={1,2,2,3,4,4,5,5} # remove duplication
print(set_var)
# Out:
# {1, 2, 3, 4, 5}

# %%
set_var={"avengers","hitman","batman","superman"}
print(set_var)
type(set_var)
# Out:
# {'hitman', 'superman', 'batman', 'avengers'}
# set

# %%
#in set you will not do the indexing operation
#inbuild function 
set_var.add("hulk")

# %%
set_var.add("Xmen")
set_var#allocate randomly because set is unordered of the collection
# Out:
# {'X-men', 'Xmen', 'avengers', 'batman', 'hitman', 'hulk', 'superman'}

# %%
set1={"yash", "shruti","tanish"}
set2={"yash", "shruti", "tanish", "tejaswa"}
set1.difference(set2)
print(set1)
set2.difference(set1)
print(set2)
# Out:
# {'yash', 'tanish', 'shruti'}
# {'yash', 'tanish', 'tejaswa', 'shruti'}

# %%
set2.difference_update(set1)
print(set2)
# Out:
# {'tejaswa'}

# %%
print(set2.intersection(set1))
# Out:
# set()

# %%
set1 = {"hulk", "batman", "superman"}
set2 = {"hulk", "thor", "ironman"}
set2.intersection(set1)
# Out:
# {'hulk'}

# %%
dic={}
type(dic)
# Out:
# dict
