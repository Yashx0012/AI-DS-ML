# %%
10 * ("str")
# Out:
# 'strstrstrstrstrstrstrstrstrstr'

# %%
type(10)
# Out:
# int

# %%
type(10.0)
# Out:
# float

# %%
type('str')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
a=10
type(a)
# Out:
# int

# %%
a='yash baraskar'
type(a)
# Out:
# str

# %%
a=10
b=20
print(a*b)
print(a/b)
print(a-b)
print(a+b)
# Out:
# 200
# 0.5
# -10
# 30

# %%
a=10 
b=20
print((a/b)+(a*b))
# Out:
# 200.5

# %%
firstname='yash'
lastname='baraskar'
print('my first name is {} and my last name is {}'.format(firstname,lastname)) # when i want to dynamic way of printing and some complex sentence
# Out:
# my first name is yash and my last name is baraskar

# %%
firstname='yash'
lastname='baraskar'
print('my first name is {a} and my last name is {b}'.format(b=lastname,a=firstname)) #if the order is change of first and last names
# Out:
# my first name is yash and my last name is baraskar

# %%
len('YASHBARASKAR')
# Out:
# 12

# %%
n='Y a s h B a r  a s k a r'
print(n.isalnum())#check if all char are number 
print(n.isalpha())
print(n.title())
print(n.isdigit())
print(n.islower())
print(n.isupper())
print(n.isspace())
print(n.endswith('r'))
print(n.startswith('t'))
# Out:
# False
# False
# Y A S H B A R  A S K A R
# False
# False
# False
# False
# True
# False

# %%
n = '1234'
print(n.isdigit())
# Out:
# True
